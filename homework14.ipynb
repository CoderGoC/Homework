# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import sklearn as sk

# %%
Insurance = pd.read_csv("insurance.csv")
Insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
Insurance["sex"].describe()
# Out:
# count     1338
# unique       2
# top       male
# freq       676
# Name: sex, dtype: object

# %%
Insurance["smoker"].describe()
# Out:
# count     1338
# unique       2
# top         no
# freq      1064
# Name: smoker, dtype: object

# %%
Insurance["sex"].value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64

# %%
Insurance["smoker"].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %% [markdown]
# Categorical datani bu DF dagi One hot encoding boyicha k dummy variable boyicha categoricaldan numberic ka otkazin koramiz

# %%
pd.get_dummies(Insurance,dtype=int)
# Out:
#       age     bmi  children      charges  sex_female  sex_male  smoker_no  \
# 0      19  27.900         0  16884.92400           1         0          0
# 1      18  33.770         1   1725.55230           0         1          1
# 2      28  33.000         3   4449.46200           0         1          1
# 3      33  22.705         0  21984.47061           0         1          1
# 4      32  28.880         0   3866.85520           0         1          1
# ...   ...     ...       ...          ...         ...       ...        ...
# 1333   50  30.970         3  10600.54830           0         1          1
# 1334   18  31.920         0   2205.98080           1         0          1
# 1335   18  36.850         0   1629.83350           1         0          1
# 1336   21  25.800         0   2007.94500           1         0          1
# 1337   61  29.070         0  29141.36030           1         0          0
#
#       smoker_yes  region_northeast  region_northwest  region_southeast  \
# ...

# %% [markdown]
# Bunda biz korishimiz mumkinki, barcha variablelarni alohidadan encoding qilib oldik

# %%
pd.get_dummies(Insurance,columns=['sex'], dtype=int)
# Out:
#       age     bmi  children smoker     region      charges  sex_female  \
# 0      19  27.900         0    yes  southwest  16884.92400           1
# 1      18  33.770         1     no  southeast   1725.55230           0
# 2      28  33.000         3     no  southeast   4449.46200           0
# 3      33  22.705         0     no  northwest  21984.47061           0
# 4      32  28.880         0     no  northwest   3866.85520           0
# ...   ...     ...       ...    ...        ...          ...         ...
# 1333   50  30.970         3     no  northwest  10600.54830           0
# 1334   18  31.920         0     no  northeast   2205.98080           1
# 1335   18  36.850         0     no  southeast   1629.83350           1
# 1336   21  25.800         0     no  southwest   2007.94500           1
# 1337   61  29.070         0    yes  northwest  29141.36030           1
#
#       sex_male
# 0            0
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# ...

# %%
pd.get_dummies(Insurance,columns=['smoker'], dtype=int)
# Out:
#       age     sex     bmi  children     region      charges  smoker_no  \
# 0      19  female  27.900         0  southwest  16884.92400          0
# 1      18    male  33.770         1  southeast   1725.55230          1
# 2      28    male  33.000         3  southeast   4449.46200          1
# 3      33    male  22.705         0  northwest  21984.47061          1
# 4      32    male  28.880         0  northwest   3866.85520          1
# ...   ...     ...     ...       ...        ...          ...        ...
# 1333   50    male  30.970         3  northwest  10600.54830          1
# 1334   18  female  31.920         0  northeast   2205.98080          1
# 1335   18  female  36.850         0  southeast   1629.83350          1
# 1336   21  female  25.800         0  southwest   2007.94500          1
# 1337   61  female  29.070         0  northwest  29141.36030          0
#
#       smoker_yes
# 0              1
# 1              0
# 2              0
# 3              0
# 4              0
# ...

# %% [markdown]
# Ozimiz uchun ham moslab olishimiz mumkin bu set ni

# %%
df_with_dummies = pd.get_dummies(Insurance, columns=['sex'], prefix="Jins",prefix_sep=" ", dtype=int)
df_with_dummies
# Out:
#       age     bmi  children smoker     region      charges  Jins female  \
# 0      19  27.900         0    yes  southwest  16884.92400            1
# 1      18  33.770         1     no  southeast   1725.55230            0
# 2      28  33.000         3     no  southeast   4449.46200            0
# 3      33  22.705         0     no  northwest  21984.47061            0
# 4      32  28.880         0     no  northwest   3866.85520            0
# ...   ...     ...       ...    ...        ...          ...          ...
# 1333   50  30.970         3     no  northwest  10600.54830            0
# 1334   18  31.920         0     no  northeast   2205.98080            1
# 1335   18  36.850         0     no  southeast   1629.83350            1
# 1336   21  25.800         0     no  southwest   2007.94500            1
# 1337   61  29.070         0    yes  northwest  29141.36030            1
#
#       Jins male
# 0             0
# 1             1
# 2             1
# 3             1
# ...

# %%
df_with_dummies = pd.get_dummies(Insurance, columns=['smoker'], prefix="Chekadi",prefix_sep=" ", dtype=int)
df_with_dummies
# Out:
#       age     sex     bmi  children     region      charges  Chekadi no  \
# 0      19  female  27.900         0  southwest  16884.92400           0
# 1      18    male  33.770         1  southeast   1725.55230           1
# 2      28    male  33.000         3  southeast   4449.46200           1
# 3      33    male  22.705         0  northwest  21984.47061           1
# 4      32    male  28.880         0  northwest   3866.85520           1
# ...   ...     ...     ...       ...        ...          ...         ...
# 1333   50    male  30.970         3  northwest  10600.54830           1
# 1334   18  female  31.920         0  northeast   2205.98080           1
# 1335   18  female  36.850         0  southeast   1629.83350           1
# 1336   21  female  25.800         0  southwest   2007.94500           1
# 1337   61  female  29.070         0  northwest  29141.36030           0
#
#       Chekadi yes
# 0               1
# 1               0
# 2               0
# 3               0
# ...

# %% [markdown]
# Bunda biz ayitishimiz mumkinki data frameni manosi saqlab qolindi va ozimizga ancha tushunarli qilib olindi

# %% [markdown]
# Endi buni yanada qisqartirishimiz mumkin yani k-1 variable boyicha bitta turni tashlab yuborgan holda data ni manosin saqlab qolamiz

# %%
df_with_dummies = pd.get_dummies(Insurance, columns=['sex'], prefix="jins", drop_first=True, dtype=int)
df_with_dummies
# Out:
#       age     bmi  children smoker     region      charges  jins_male
# 0      19  27.900         0    yes  southwest  16884.92400          0
# 1      18  33.770         1     no  southeast   1725.55230          1
# 2      28  33.000         3     no  southeast   4449.46200          1
# 3      33  22.705         0     no  northwest  21984.47061          1
# 4      32  28.880         0     no  northwest   3866.85520          1
# ...   ...     ...       ...    ...        ...          ...        ...
# 1333   50  30.970         3     no  northwest  10600.54830          1
# 1334   18  31.920         0     no  northeast   2205.98080          0
# 1335   18  36.850         0     no  southeast   1629.83350          0
# 1336   21  25.800         0     no  southwest   2007.94500          0
# 1337   61  29.070         0    yes  northwest  29141.36030          0
#
# [1338 rows x 7 columns]

# %%
df_with_dummies = pd.get_dummies(Insurance, columns=['smoker'], prefix="Chekadi", drop_first=True, dtype=int)
df_with_dummies
# Out:
#       age     sex     bmi  children     region      charges  Chekadi_yes
# 0      19  female  27.900         0  southwest  16884.92400            1
# 1      18    male  33.770         1  southeast   1725.55230            0
# 2      28    male  33.000         3  southeast   4449.46200            0
# 3      33    male  22.705         0  northwest  21984.47061            0
# 4      32    male  28.880         0  northwest   3866.85520            0
# ...   ...     ...     ...       ...        ...          ...          ...
# 1333   50    male  30.970         3  northwest  10600.54830            0
# 1334   18  female  31.920         0  northeast   2205.98080            0
# 1335   18  female  36.850         0  southeast   1629.83350            0
# 1336   21  female  25.800         0  southwest   2007.94500            0
# 1337   61  female  29.070         0  northwest  29141.36030            1
#
# [1338 rows x 7 columns]

# %% [markdown]
# K-1 dummies boyicha bitta qatorni tashlab yubordik. Yani qolgan barcha turlarda bu data 0 bolsa biz tashlab yuborgan tur mavjud ekanligini ifodalaydi va DF ni ancha visibility sini yaxshilaydi

# %% [markdown]
# ### Bu yuqorida qiglan barcha ishlarimiz uchun xulosa qiladigan bolsak, One hot encoding orqalik biz categorical datani numeric ka otkazib DF ustida opertionlarni amalga oshirishga moslab olinadi. Bu bizga kengi search worklarda foydalik boladi

# %% [markdown]
# ## Label / Ordinal / Integer encoding

# %% [markdown]
# Bu encoding uchun biz boshqa kutubxona chaqirib olamiz

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Bu scikit-learn kutobxonasiga tegishlik bolgan methodlardan biridir

# %% [markdown]
# Endi buni biz Ordinal encoding boyicha ozgartiruvchi kiritib encoding qilib olamiz Iris DF dagi species column ni

# %%
le = LabelEncoder()
Insurance['Jinslar'] = le.fit_transform(Insurance['sex'])
Insurance
# Out:
#       age     sex     bmi  children smoker     region      charges  Jinslar
# 0      19  female  27.900         0    yes  southwest  16884.92400        0
# 1      18    male  33.770         1     no  southeast   1725.55230        1
# 2      28    male  33.000         3     no  southeast   4449.46200        1
# 3      33    male  22.705         0     no  northwest  21984.47061        1
# 4      32    male  28.880         0     no  northwest   3866.85520        1
# ...   ...     ...     ...       ...    ...        ...          ...      ...
# 1333   50    male  30.970         3     no  northwest  10600.54830        1
# 1334   18  female  31.920         0     no  northeast   2205.98080        0
# 1335   18  female  36.850         0     no  southeast   1629.83350        0
# 1336   21  female  25.800         0     no  southwest   2007.94500        0
# 1337   61  female  29.070         0    yes  northwest  29141.36030        0
#
# [1338 rows x 8 columns]

# %%
Insurance['Chekish'] = le.fit_transform(Insurance['smoker'])
Insurance
# Out:
#       age     sex     bmi  children smoker     region      charges  Jinslar  \
# 0      19  female  27.900         0    yes  southwest  16884.92400        0
# 1      18    male  33.770         1     no  southeast   1725.55230        1
# 2      28    male  33.000         3     no  southeast   4449.46200        1
# 3      33    male  22.705         0     no  northwest  21984.47061        1
# 4      32    male  28.880         0     no  northwest   3866.85520        1
# ...   ...     ...     ...       ...    ...        ...          ...      ...
# 1333   50    male  30.970         3     no  northwest  10600.54830        1
# 1334   18  female  31.920         0     no  northeast   2205.98080        0
# 1335   18  female  36.850         0     no  southeast   1629.83350        0
# 1336   21  female  25.800         0     no  southwest   2007.94500        0
# 1337   61  female  29.070         0    yes  northwest  29141.36030        0
#
#       Chekish
# 0           1
# 1           0
# ...

# %% [markdown]
# Bunda biz Turlar degan yangi column qoshib uni ordinal encoding boycha scikit-learn library yordamida 0 1 va 2 lar yordamida encoding qilib oldik

# %% [markdown]
# Biz bu operationni scikit-learn librarysiz pandas da qilib koramiz. Bunda bizga pandasning factorize methodi kerak boladi

# %%
pd.factorize(Insurance["sex"])
# Out:
# (array([0, 1, 1, ..., 0, 0, 0]), Index(['female', 'male'], dtype='object'))

# %%
pd.factorize(Insurance["smoker"])
# Out:
# (array([0, 1, 1, ..., 1, 1, 0]), Index(['yes', 'no'], dtype='object'))

# %% [markdown]
# Bu bizga tuple qaytaradi va undan ozimizga kerakli bolgan datani qirqib olamiz

# %%
Insurance["Jinslar1"] = pd.factorize(Insurance["sex"])[0]
Insurance
# Out:
#       age     sex     bmi  children smoker     region      charges  Jinslar  \
# 0      19  female  27.900         0    yes  southwest  16884.92400        0
# 1      18    male  33.770         1     no  southeast   1725.55230        1
# 2      28    male  33.000         3     no  southeast   4449.46200        1
# 3      33    male  22.705         0     no  northwest  21984.47061        1
# 4      32    male  28.880         0     no  northwest   3866.85520        1
# ...   ...     ...     ...       ...    ...        ...          ...      ...
# 1333   50    male  30.970         3     no  northwest  10600.54830        1
# 1334   18  female  31.920         0     no  northeast   2205.98080        0
# 1335   18  female  36.850         0     no  southeast   1629.83350        0
# 1336   21  female  25.800         0     no  southwest   2007.94500        0
# 1337   61  female  29.070         0    yes  northwest  29141.36030        0
#
#       Chekish  Jinslar1
# 0           1         0
# ...

# %%
Insurance["Checkadi1"] = pd.factorize(Insurance["smoker"])[0]
Insurance
# Out:
#       age     sex     bmi  children smoker     region      charges  Jinslar  \
# 0      19  female  27.900         0    yes  southwest  16884.92400        0
# 1      18    male  33.770         1     no  southeast   1725.55230        1
# 2      28    male  33.000         3     no  southeast   4449.46200        1
# 3      33    male  22.705         0     no  northwest  21984.47061        1
# 4      32    male  28.880         0     no  northwest   3866.85520        1
# ...   ...     ...     ...       ...    ...        ...          ...      ...
# 1333   50    male  30.970         3     no  northwest  10600.54830        1
# 1334   18  female  31.920         0     no  northeast   2205.98080        0
# 1335   18  female  36.850         0     no  southeast   1629.83350        0
# 1336   21  female  25.800         0     no  southwest   2007.94500        0
# 1337   61  female  29.070         0    yes  northwest  29141.36030        0
#
#       Chekish  Jinslar1  Checkadi1
# ...

# %% [markdown]
# Xulosa qilsak bu uchun, in both ways, we could get the same result and noted them in our DF so that it would be easy to use in our futher researches

# %% [markdown]
# ### Handling Outlier

# %%
Insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges  Jinslar  \
# 0   19  female  27.900         0    yes  southwest  16884.92400        0
# 1   18    male  33.770         1     no  southeast   1725.55230        1
# 2   28    male  33.000         3     no  southeast   4449.46200        1
# 3   33    male  22.705         0     no  northwest  21984.47061        1
# 4   32    male  28.880         0     no  northwest   3866.85520        1
#
#    Chekish  Jinslar1  Checkadi1
# 0        1         0          0
# 1        0         1          1
# 2        0         1          1
# 3        0         1          1
# 4        0         1          1

# %%
sns.boxplot(Insurance[["bmi","age"]])
plt.show()

# %% [markdown]
# Age da outlier yoq  ekan va  u normal distributionga tushyapti shunchun uni outlierlarni handle qilmaymiz. Lekin bmi ustida biroz ish olib boramiz

# %%
sns.boxplot(Insurance['charges'])
plt.show()

# %% [markdown]
# Charges columnda yuqorida koringanidek ancha miqdorda outlierlar mavjud qoshimchasiga bu normal distributionga ham tushmayapti. Bu bizga shuni anglatadiki, agar biz har qancha outlarni yoqotsak ham yangi outlierlar kelib chiqaveradi setdan kelib chiqqan holda

# %% [markdown]
# Bizda hozir bmi va charges uchun chizgan boxplotlarimizi korsak ularda outlierlar mavjud va biz hozir ular bilan ishlaymiz
# Bunda bizda 2ta outlier bor colunms uchun plotlarni show qilish functionlarini yozvolamiz.

# %%
def plot_bmi(Old, New):
    fig, ax = plt.subplots(ncols=2, nrows=1,figsize=(17,7))
    sns.boxplot(Old["bmi"],ax=ax[0])
    ax[0].title.set_text("BMI with outliers")
    sns.boxplot(New["bmi"],ax=ax[1])
    ax[1].title.set_text("BMI without outliers")
    ax[0].set_xlabel('BMI')
    ax[1].set_xlabel('BMI')
    
    plt.show()
  

def plot_charges(Old, New):
    fig, ax = plt.subplots(ncols=2, nrows=1,figsize=(17,7))
    sns.boxplot(Old["charges"],ax=ax[0])
    ax[0].title.set_text("Charges with outliers")
    sns.boxplot(New["charges"],ax=ax[1])
    ax[1].title.set_text("CHarges without outliers")
    ax[0].set_xlabel('Charges')
    ax[1].set_xlabel('Charges')
    
    plt.show()
    
  
def remove_outliers(data, function):
  numeric_columns = data.select_dtypes(include=['number']).columns
  copied_data = data.copy()
  for col in numeric_columns:
      lower_limit, upper_limit = function(copied_data, col)
      copied_data = copied_data[(copied_data[col] >= lower_limit) & (copied_data[col] <= upper_limit)]
  
  return copied_data

# %% [markdown]
# Biz bunda hozir har qanday data set uchun ishlatilishi mumkin bolgan fuctionlarni yozib oldik. Bular yordamida biz boxplotlarni chizamiz va outlierni bemalol remove qilsak boladi.

# %% [markdown]
# ## Gaussian distribution (mean and std)

# %%
data = pd.read_csv("insurance.csv")
def Gaussian_distribution(data, col):
    mean = data[col].mean()
    std = data[col].std()
    lower_limit = mean - 3 * std
    upper_limit = mean + 3 * std
    return lower_limit, upper_limit

data_no_outliers_gaussian = remove_outliers(data, Gaussian_distribution)
plot_bmi(data, data_no_outliers_gaussian)
plot_charges(data, data_no_outliers_gaussian)

# %% [markdown]
# #### Xulosa qiladigan bolsak bunda biz hozir, ikkala column uchun ham yozilgan functionlada outlierlar mutloqo yoqolmadi lekin ularning data set ga tasirini kopaytirmagan holda malum chegaragacha kamaytirildi. Bunda biz birinchi nazariya  • Gaussian distribution (mean and std) nazariyasi va formulalaridan foydalandik va keraklik natijalarga qisman erishdik. Data setni ancha normallashtirdik

# %% [markdown]
# ### IQR proximity rule

# %%
data = pd.read_csv("insurance.csv")

def IQR_proximity_rule(data, col):
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR
    return lower_limit, upper_limit

data_no_outliers_iqr = remove_outliers(data, IQR_proximity_rule)

plot_bmi(data, data_no_outliers_iqr)
plot_charges(data, data_no_outliers_iqr)

# %% [markdown]
# #### Bunda ham huddi shunday hulosaga kelsak boladi, yani set dagi malum bir outlierlar IQR proximity rule metodi asosida chiqarib yuborildi.  Charges columnda data miqdori ancha kop va outlierlar ham yetarli darajada kopligini hisobga olgan holda max darajada outlierlar qisqartirildi va set normallashtirildi

# %% [markdown]
# ### Quantiles (5% and 95%)

# %%
data = pd.read_csv("insurance.csv")


def Quantiles(data, col):
    lower_limit = data[col].quantile(0.05)
    upper_limit = data[col].quantile(0.95)
    return lower_limit, upper_limit
  
data_no_outliers_quantiles = remove_outliers(data, Quantiles)
plot_bmi(data, data_no_outliers_quantiles)
plot_charges(data, data_no_outliers_quantiles)

# %% [markdown]
# #### Quantiles methodida ham outlierlar miqdori kamayptirilda va set normallashtirildi ancha

# %% [markdown]
# ### Umumiy hulosa qiladigan bolsak bugungi ish haqida,Ishning birinchi qismida biz barcha encoding turlari boyicha ishlashni va ularning manolarini hamda DF da qanday foydalana olish mumkinligini korib chiqdik.
# ### Ikkinchi qismida esa outlier larni handling qilishni 3ta method i yordamida korib chiqdik         -- Guassian                                                                                           -- IQR proximity rule                                                                                 -- Quantiles (5% and 95%)
# ### 3ta column boyicha kordik biz, age da outlier yoqqligi uchun uni ozgartirmadik. bmi va charges mos ravishda outlierlarga ega ekan. Ularni yuqoridagi 2ta methodda normallashtirdik. Lekin Charges normal distributionga tushmagani uchun unda outlierar miqdori yoqolib ketmadi. Biroq max darajada qisqartirildi va set ga moslandi mohiyatini yoqotmagan holda
