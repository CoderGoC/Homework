# %%
import pandas as pd

# %% [markdown]
# #### HOMEWORK for 4st lesson

# %%
df = pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# To print DF

# %%
print(df)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# To identify Columns and index

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# Bunda bizda 8 ta ozgaruvchi yani column va 1000 ta qiymat indexlab berilgan.

# %% [markdown]
# Setting a column as the index

# %%
df_index = df.set_index("race/ethnicity")
df_index
# Out:
#                 gender parental level of education         lunch  \
# race/ethnicity
# group B         female           bachelor's degree      standard
# group C         female                some college      standard
# group B         female             master's degree      standard
# group A           male          associate's degree  free/reduced
# group C           male                some college      standard
# ...                ...                         ...           ...
# group E         female             master's degree      standard
# group C           male                 high school  free/reduced
# group C         female                 high school  free/reduced
# group D         female                some college      standard
# group D         female                some college  free/reduced
#
#                test preparation course  math score  reading score  \
# race/ethnicity
# group B                           none          72             72
# ...

# %%
df_index = df.set_index("gender")
df_index
# Out:
#        race/ethnicity parental level of education         lunch  \
# gender
# female        group B           bachelor's degree      standard
# female        group C                some college      standard
# female        group B             master's degree      standard
# male          group A          associate's degree  free/reduced
# male          group C                some college      standard
# ...               ...                         ...           ...
# female        group E             master's degree      standard
# male          group C                 high school  free/reduced
# female        group C                 high school  free/reduced
# female        group D                some college      standard
# female        group D                some college  free/reduced
#
#        test preparation course  math score  reading score  writing score
# gender
# female                    none          72             72             74
# ...

# %% [markdown]
# Removing and Dropping an index

# %%
df_index.reset_index()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df_index.reset_index(drop=True)
# Out:
#     race/ethnicity parental level of education         lunch  \
# 0          group B           bachelor's degree      standard
# 1          group C                some college      standard
# 2          group B             master's degree      standard
# 3          group A          associate's degree  free/reduced
# 4          group C                some college      standard
# ..             ...                         ...           ...
# 995        group E             master's degree      standard
# 996        group C                 high school  free/reduced
# 997        group C                 high school  free/reduced
# 998        group D                some college      standard
# 999        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# ...

# %% [markdown]
# Xulosa qilib aytsak, biz bu methodlar yordamida o'zgargan DF ni reset qildik va keyin ma'lum bir qatorni drop qilib yubordik. Bunda asosan biz o'zgartirgan qator drop qilinadi.

# %% [markdown]
# Making subsetting with the help of the isin and loc as well as iloc

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df[df["gender"].isin(["male"])]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# ..     ...            ...                         ...           ...
# 985   male        group A                 high school      standard
# 987   male        group E            some high school      standard
# 990   male        group E                 high school  free/reduced
# 994   male        group A                 high school      standard
# 996   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# ...

# %%
df[df["gender"].isin(["female"])]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# Bunda biz isin method i yordamida o'zimiz uchun kerakli ma'lumotlarni olishimiz mukin aniq nameni kirish bilan

# %%
df_index = df.set_index("gender")
df_index
# Out:
#        race/ethnicity parental level of education         lunch  \
# gender
# female        group B           bachelor's degree      standard
# female        group C                some college      standard
# female        group B             master's degree      standard
# male          group A          associate's degree  free/reduced
# male          group C                some college      standard
# ...               ...                         ...           ...
# female        group E             master's degree      standard
# male          group C                 high school  free/reduced
# female        group C                 high school  free/reduced
# female        group D                some college      standard
# female        group D                some college  free/reduced
#
#        test preparation course  math score  reading score  writing score
# gender
# female                    none          72             72             74
# ...

# %%
df_ind1 = df.set_index("gender")
df_ind1
# Out:
#        race/ethnicity parental level of education         lunch  \
# gender
# female        group B           bachelor's degree      standard
# female        group C                some college      standard
# female        group B             master's degree      standard
# male          group A          associate's degree  free/reduced
# male          group C                some college      standard
# ...               ...                         ...           ...
# female        group E             master's degree      standard
# male          group C                 high school  free/reduced
# female        group C                 high school  free/reduced
# female        group D                some college      standard
# female        group D                some college  free/reduced
#
#        test preparation course  math score  reading score  writing score
# gender
# female                    none          72             72             74
# ...

# %%
df_ind1.loc["male"]
# Out:
#        race/ethnicity parental level of education         lunch  \
# gender
# male          group A          associate's degree  free/reduced
# male          group C                some college      standard
# male          group B                some college  free/reduced
# male          group D                 high school  free/reduced
# male          group C          associate's degree      standard
# ...               ...                         ...           ...
# male          group A                 high school      standard
# male          group E            some high school      standard
# male          group E                 high school  free/reduced
# male          group A                 high school      standard
# male          group C                 high school  free/reduced
#
#        test preparation course  math score  reading score  writing score
# gender
# male                      none          47             57             44
# ...

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df_ind2 = df.set_index(["gender","race/ethnicity"])
df_ind2
# Out:
#                       parental level of education         lunch  \
# gender race/ethnicity
# female group B                  bachelor's degree      standard
#        group C                       some college      standard
#        group B                    master's degree      standard
# male   group A                 associate's degree  free/reduced
#        group C                       some college      standard
# ...                                           ...           ...
# female group E                    master's degree      standard
# male   group C                        high school  free/reduced
# female group C                        high school  free/reduced
#        group D                       some college      standard
#        group D                       some college  free/reduced
#
#                       test preparation course  math score  reading score  \
# gender race/ethnicity
# female group B                           none          72             72
# ...

# %%
df_ind2.loc[[('male', 'group E')]]
# Out:
#                       parental level of education         lunch  \
# gender race/ethnicity
# male   group E                       some college      standard
#        group E                 associate's degree      standard
#        group E                       some college      standard
#        group E                 associate's degree  free/reduced
#        group E                  bachelor's degree  free/reduced
# ...                                           ...           ...
#        group E                 associate's degree  free/reduced
#        group E                        high school      standard
#        group E                 associate's degree      standard
#        group E                   some high school      standard
#        group E                        high school  free/reduced
#
#                       test preparation course  math score  reading score  \
# gender race/ethnicity
# male   group E                           none          97             87
# ...

# %%
df_ind2.loc[[('female', 'group A')]]
# Out:
#                       parental level of education         lunch  \
# gender race/ethnicity
# female group A                    master's degree      standard
#        group A                 associate's degree      standard
#        group A                 associate's degree  free/reduced
#        group A                       some college      standard
#        group A                  bachelor's degree      standard
#        group A                   some high school  free/reduced
#        group A                   some high school      standard
#        group A                   some high school  free/reduced
#        group A                       some college  free/reduced
#        group A                   some high school      standard
#        group A                   some high school  free/reduced
#        group A                   some high school  free/reduced
#        group A                        high school  free/reduced
# ...

# %% [markdown]
# Xulosa qilib aytsak, bunda biz berilgan indexlar boyicha filterlab oldik.

# %% [markdown]
# Sorting by index values

# %%
df_ind2.sort_index()
# Out:
#                       parental level of education         lunch  \
# gender race/ethnicity
# female group A                    master's degree      standard
#        group A                 associate's degree      standard
#        group A                 associate's degree  free/reduced
#        group A                       some college      standard
#        group A                  bachelor's degree      standard
# ...                                           ...           ...
# male   group E                 associate's degree  free/reduced
#        group E                        high school      standard
#        group E                 associate's degree      standard
#        group E                   some high school      standard
#        group E                        high school  free/reduced
#
#                       test preparation course  math score  reading score  \
# gender race/ethnicity
# female group A                           none          50             53
# ...

# %%
df_ind3 = df.set_index("math score")
df_ind3
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# math score
# 72          female        group B           bachelor's degree      standard
# 69          female        group C                some college      standard
# 90          female        group B             master's degree      standard
# 47            male        group A          associate's degree  free/reduced
# 76            male        group C                some college      standard
# ...            ...            ...                         ...           ...
# 88          female        group E             master's degree      standard
# 62            male        group C                 high school  free/reduced
# 59          female        group C                 high school  free/reduced
# 68          female        group D                some college      standard
# 77          female        group D                some college  free/reduced
#
# ...

# %%
df_ind3.sort_index()
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# math score
# 0           female        group C            some high school  free/reduced
# 8           female        group B                 high school  free/reduced
# 18          female        group B            some high school  free/reduced
# 19          female        group B                some college      standard
# 22          female        group C                some college  free/reduced
# ...            ...            ...                         ...           ...
# 100         female        group E          associate's degree      standard
# 100           male        group D                some college      standard
# 100           male        group E           bachelor's degree      standard
# 100         female        group E           bachelor's degree      standard
# 100         female        group E                some college      standard
#
# ...

# %%
df_ind3.sort_index(level=["math score"], ascending=[False])
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# math score
# 100         female        group E          associate's degree      standard
# 100         female        group E           bachelor's degree      standard
# 100           male        group E          associate's degree  free/reduced
# 100           male        group D                some college      standard
# 100           male        group E           bachelor's degree      standard
# ...            ...            ...                         ...           ...
# 22          female        group C                some college  free/reduced
# 19          female        group B                some college      standard
# 18          female        group B            some high school  free/reduced
# 8           female        group B                 high school  free/reduced
# 0           female        group C            some high school  free/reduced
#
# ...

# %%
df_ind3.sort_index(level=["math score"], ascending=[True])
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# math score
# 0           female        group C            some high school  free/reduced
# 8           female        group B                 high school  free/reduced
# 18          female        group B            some high school  free/reduced
# 19          female        group B                some college      standard
# 22          female        group C                some college  free/reduced
# ...            ...            ...                         ...           ...
# 100         female        group E          associate's degree      standard
# 100           male        group D                some college      standard
# 100           male        group E           bachelor's degree      standard
# 100         female        group E           bachelor's degree      standard
# 100         female        group E                some college      standard
#
# ...

# %% [markdown]
# Bunda biz ozimiz asos qilib olgan index qiymatlari boyicha osish va kamayish tartibida sortlab ko'rdik

# %% [markdown]
# Slicing lists

# %%
qator = df.columns
qator
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
qator[2:5]
# Out:
# Index(['parental level of education', 'lunch', 'test preparation course'], dtype='object')

# %%
qator[:3]
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education'], dtype='object')

# %% [markdown]
# Sort the index before slicing it

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df_sort = df.set_index(["math score"]).sort_index()
df_sort
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# math score
# 0           female        group C            some high school  free/reduced
# 8           female        group B                 high school  free/reduced
# 18          female        group B            some high school  free/reduced
# 19          female        group B                some college      standard
# 22          female        group C                some college  free/reduced
# ...            ...            ...                         ...           ...
# 100         female        group E          associate's degree      standard
# 100           male        group D                some college      standard
# 100           male        group E           bachelor's degree      standard
# 100         female        group E           bachelor's degree      standard
# 100         female        group E                some college      standard
#
# ...

# %% [markdown]
# Bunda biz qirqishdan oldin sortlab keyin qirqib olamiz
