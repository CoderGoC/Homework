# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import sklearn as sk

# %%
df = pd.read_csv("https://assets.datacamp.com/production/repositories/2210/datasets/794e0759b73a2d80baa5d8fb88636a47965139d3/college_datav3.csv")
df.head()
# Out:
#                                 INSTNM    OPEID  REGION  SAT_AVG_ALL  PCTPELL  \
# 0             Alabama A & M University   100200       5        850.0   0.7249
# 1  University of Alabama at Birmingham   105200       5       1147.0   0.3505
# 2                   Amridge University  2503400       5          NaN   0.7455
# 3  University of Alabama in Huntsville   105500       5       1221.0   0.3179
# 4             Alabama State University   100500       5        844.0   0.7567
#
#    PCTFLOAN  ADM_RATE_ALL       UG  AVGFACSAL COMPL_RPY_5YR_RT  ... CONTROL  \
# 0    0.8159      0.653841   4380.0     7017.0      0.477631579  ...       1
# 1    0.5218      0.604275  10331.0    10221.0      0.673230442  ...       1
# 2    0.8781           NaN     98.0     3217.0      0.636363636  ...       2
# 3    0.4589      0.811971   5220.0     9514.0      0.762222222  ...       1
# 4    0.7692      0.463858   4348.0     7940.0       0.43006993  ...       1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6702 entries, 0 to 6701
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   INSTNM            6702 non-null   object
#  1   OPEID             6702 non-null   int64
#  2   REGION            6702 non-null   int64
#  3   SAT_AVG_ALL       1387 non-null   float64
#  4   PCTPELL           6066 non-null   float64
#  5   PCTFLOAN          6066 non-null   float64
#  6   ADM_RATE_ALL      2180 non-null   float64
#  7   UG                4367 non-null   float64
#  8   AVGFACSAL         4104 non-null   float64
#  9   COMPL_RPY_5YR_RT  5708 non-null   object
#  10  DEBT_MDN          6681 non-null   object
#  11  MEDIAN_HH_INC     4993 non-null   object
#  12  ICLEVEL           6702 non-null   int64
#  13  HIGHDEG           6702 non-null   int64
#  14  CONTROL           6702 non-null   int64
#  15  WOMENONLY         6368 non-null   float64
# ...

# %% [markdown]
# info yordamida malumotlar haqida informatsiya oldik. Bizda null yani NaN lar mavjud ekan

# %%
df.describe()
# Out:
#               OPEID       REGION  SAT_AVG_ALL      PCTPELL     PCTFLOAN  \
# count  6.702000e+03  6702.000000  1387.000000  6066.000000  6066.000000
# mean   1.788528e+06     4.602954  1065.332372     0.502318     0.490676
# std    3.304120e+06     2.177145   134.879236     0.220404     0.279644
# min    1.002000e+05     0.000000   708.000000     0.000000     0.000000
# 25%    3.188250e+05     3.000000   981.500000     0.338525     0.285725
# 50%    1.005302e+06     5.000000  1048.000000     0.483850     0.548200
# 75%    2.598900e+06     6.000000  1127.000000     0.666700     0.704500
# max    8.209884e+07     9.000000  1544.000000     1.000000     1.000000
#
#        ADM_RATE_ALL            UG     AVGFACSAL      ICLEVEL      HIGHDEG  \
# count   2180.000000   4367.000000   4104.000000  6702.000000  6702.000000
# mean       0.681821   2945.242501   6451.342105     1.811698     2.276783
# std        0.204033   4974.178446   2376.043146     0.817686     1.324162
# ...

# %% [markdown]
# Bunda bizda data biroz kopligi uchun korish qiyinroq bolyapti

# %% [markdown]
# Null lar haqida malumot olamiz

# %%
df.isnull().sum()
# Out:
# INSTNM                 0
# OPEID                  0
# REGION                 0
# SAT_AVG_ALL         5315
# PCTPELL              636
# PCTFLOAN             636
# ADM_RATE_ALL        4522
# UG                  2335
# AVGFACSAL           2598
# COMPL_RPY_5YR_RT     994
# DEBT_MDN              21
# MEDIAN_HH_INC       1709
# ICLEVEL                0
# HIGHDEG                0
# CONTROL                0
# WOMENONLY            334
# MENONLY              334
# LOCALE               334
# Tuition              967
# Degree_Type            0
# Ownership              0
# Regions                0
# Locales              334
# Locale_Short         337
# dtype: int64

# %% [markdown]
# koringanidek bizda null lar mavjud ularni bazilarini tozalashga harakat qilib koramiz

# %%
df.isnull().mean()*100
# Out:
# INSTNM               0.000000
# OPEID                0.000000
# REGION               0.000000
# SAT_AVG_ALL         79.304685
# PCTPELL              9.489705
# PCTFLOAN             9.489705
# ADM_RATE_ALL        67.472396
# UG                  34.840346
# AVGFACSAL           38.764548
# COMPL_RPY_5YR_RT    14.831394
# DEBT_MDN             0.313339
# MEDIAN_HH_INC       25.499851
# ICLEVEL              0.000000
# HIGHDEG              0.000000
# CONTROL              0.000000
# WOMENONLY            4.983587
# MENONLY              4.983587
# LOCALE               4.983587
# Tuition             14.428529
# Degree_Type          0.000000
# Ownership            0.000000
# Regions              0.000000
# Locales              4.983587
# Locale_Short         5.028350
# dtype: float64

# %% [markdown]
# qatorlar boyicha null larning foizdagi ulushi

# %% [markdown]
# datalarning turlarini koramiz

# %%
df.select_dtypes("object")
# Out:
#                                                  INSTNM COMPL_RPY_5YR_RT  \
# 0                              Alabama A & M University      0.477631579
# 1                   University of Alabama at Birmingham      0.673230442
# 2                                    Amridge University      0.636363636
# 3                   University of Alabama in Huntsville      0.762222222
# 4                              Alabama State University       0.43006993
# ...                                                 ...              ...
# 6697          SAE Institute of Technology San Francisco              NaN
# 6698                  Rasmussen College - Overland Park      0.598980065
# 6699  National Personal Training Institute of Cleveland              NaN
# 6700  Bay Area Medical Academy - San Jose Satellite ...              NaN
# 6701                        High Desert Medical College              NaN
#
#      DEBT_MDN MEDIAN_HH_INC Degree_Type           Ownership      Regions  \
# ...

# %% [markdown]
# Bizda object type ichida ham numeric datalar mavjud ekan kengi qiladigan ishimiz ularni numericca otkazish va tozalash boladi.

# %%
df.select_dtypes("number")
# Out:
#         OPEID  REGION  SAT_AVG_ALL  PCTPELL  PCTFLOAN  ADM_RATE_ALL       UG  \
# 0      100200       5        850.0   0.7249    0.8159      0.653841   4380.0
# 1      105200       5       1147.0   0.3505    0.5218      0.604275  10331.0
# 2     2503400       5          NaN   0.7455    0.8781           NaN     98.0
# 3      105500       5       1221.0   0.3179    0.4589      0.811971   5220.0
# 4      100500       5        844.0   0.7567    0.7692      0.463858   4348.0
# ...       ...     ...          ...      ...       ...           ...      ...
# 6697  4205801       8          NaN      NaN       NaN           NaN      NaN
# 6698   869423       4          NaN      NaN       NaN           NaN      NaN
# 6699  4220901       3          NaN      NaN       NaN           NaN      NaN
# 6700  4223701       8          NaN      NaN       NaN           NaN      NaN
# 6701  4228101       8          NaN      NaN       NaN           NaN      NaN
#
# ...

# %% [markdown]
# Bunda esa NaN lar mavjud kengi ish ularni tozalashdan iborat boladi

# %%
df[["DEBT_MDN","COMPL_RPY_5YR_RT","MEDIAN_HH_INC"]]
# Out:
#      DEBT_MDN COMPL_RPY_5YR_RT MEDIAN_HH_INC
# 0       14600      0.477631579      49720.22
# 1       14250      0.673230442      55735.22
# 2       11082      0.636363636       53683.7
# 3       15000      0.762222222      58688.62
# 4       15274       0.43006993       46065.2
# ...       ...              ...           ...
# 6697     5500              NaN           NaN
# 6698  10851.5      0.598980065           NaN
# 6699     6333              NaN           NaN
# 6700     5500              NaN           NaN
# 6701     7519              NaN           NaN
#
# [6702 rows x 3 columns]

# %% [markdown]
# bunda yuqoridagi object typedagi 3 ta numeric column larni korib oldik

# %% [markdown]
# U qatorlarning umumiy null larini qarab koramiz

# %%
df[["DEBT_MDN","COMPL_RPY_5YR_RT","MEDIAN_HH_INC"]].isnull().sum()
# Out:
# DEBT_MDN              21
# COMPL_RPY_5YR_RT     994
# MEDIAN_HH_INC       1709
# dtype: int64

# %%
df["DEBT_MDN_numeric"] = pd.to_numeric(df["DEBT_MDN"],errors="coerce")

# %%
df["COMPL_RPY_5YR_RT_numeric"] = pd.to_numeric(df["COMPL_RPY_5YR_RT"],errors="coerce")

# %%
df["MEDIAN_HH_INC_numeric"] = pd.to_numeric(df["MEDIAN_HH_INC"],errors="coerce")

# %% [markdown]
# Bunda ularning hammasini numericca otkazib chiqdik

# %%
df
# Out:
#                                                  INSTNM    OPEID  REGION  \
# 0                              Alabama A & M University   100200       5
# 1                   University of Alabama at Birmingham   105200       5
# 2                                    Amridge University  2503400       5
# 3                   University of Alabama in Huntsville   105500       5
# 4                              Alabama State University   100500       5
# ...                                                 ...      ...     ...
# 6697          SAE Institute of Technology San Francisco  4205801       8
# 6698                  Rasmussen College - Overland Park   869423       4
# 6699  National Personal Training Institute of Cleveland  4220901       3
# 6700  Bay Area Medical Academy - San Jose Satellite ...  4223701       8
# 6701                        High Desert Medical College  4228101       8
#
#       SAT_AVG_ALL  PCTPELL  PCTFLOAN  ADM_RATE_ALL       UG  AVGFACSAL  \
# ...

# %%
df.select_dtypes("number")
# Out:
#         OPEID  REGION  SAT_AVG_ALL  PCTPELL  PCTFLOAN  ADM_RATE_ALL       UG  \
# 0      100200       5        850.0   0.7249    0.8159      0.653841   4380.0
# 1      105200       5       1147.0   0.3505    0.5218      0.604275  10331.0
# 2     2503400       5          NaN   0.7455    0.8781           NaN     98.0
# 3      105500       5       1221.0   0.3179    0.4589      0.811971   5220.0
# 4      100500       5        844.0   0.7567    0.7692      0.463858   4348.0
# ...       ...     ...          ...      ...       ...           ...      ...
# 6697  4205801       8          NaN      NaN       NaN           NaN      NaN
# 6698   869423       4          NaN      NaN       NaN           NaN      NaN
# 6699  4220901       3          NaN      NaN       NaN           NaN      NaN
# 6700  4223701       8          NaN      NaN       NaN           NaN      NaN
# 6701  4228101       8          NaN      NaN       NaN           NaN      NaN
#
# ...

# %% [markdown]
# Bu jadvalda biz object typdagi datalar numeric ca otkanini korishimiz mumkin.

# %%
df.isnull().sum()
# Out:
# INSTNM                         0
# OPEID                          0
# REGION                         0
# SAT_AVG_ALL                 5315
# PCTPELL                      636
# PCTFLOAN                     636
# ADM_RATE_ALL                4522
# UG                          2335
# AVGFACSAL                   2598
# COMPL_RPY_5YR_RT             994
# DEBT_MDN                      21
# MEDIAN_HH_INC               1709
# ICLEVEL                        0
# HIGHDEG                        0
# CONTROL                        0
# WOMENONLY                    334
# MENONLY                      334
# LOCALE                       334
# Tuition                      967
# Degree_Type                    0
# Ownership                      0
# Regions                        0
# Locales                      334
# Locale_Short                 337
# DEBT_MDN_numeric             938
# COMPL_RPY_5YR_RT_numeric    2251
# MEDIAN_HH_INC_numeric       1798
# dtype: int64

# %%
df.describe()
# Out:
#               OPEID       REGION  SAT_AVG_ALL      PCTPELL     PCTFLOAN  \
# count  6.702000e+03  6702.000000  1387.000000  6066.000000  6066.000000
# mean   1.788528e+06     4.602954  1065.332372     0.502318     0.490676
# std    3.304120e+06     2.177145   134.879236     0.220404     0.279644
# min    1.002000e+05     0.000000   708.000000     0.000000     0.000000
# 25%    3.188250e+05     3.000000   981.500000     0.338525     0.285725
# 50%    1.005302e+06     5.000000  1048.000000     0.483850     0.548200
# 75%    2.598900e+06     6.000000  1127.000000     0.666700     0.704500
# max    8.209884e+07     9.000000  1544.000000     1.000000     1.000000
#
#        ADM_RATE_ALL            UG     AVGFACSAL      ICLEVEL      HIGHDEG  \
# count   2180.000000   4367.000000   4104.000000  6702.000000  6702.000000
# mean       0.681821   2945.242501   6451.342105     1.811698     2.276783
# std        0.204033   4974.178446   2376.043146     0.817686     1.324162
# ...

# %%
df["DEBT_MDN_numeric"].describe()
# Out:
# count     5764.000000
# mean     11363.965389
# std       5517.351823
# min       1109.500000
# 25%       7248.000000
# 50%       9500.000000
# 75%      14750.000000
# max      36923.000000
# Name: DEBT_MDN_numeric, dtype: float64

# %%
df["COMPL_RPY_5YR_RT_numeric"].describe()
# Out:
# count    4451.000000
# mean        0.614998
# std         0.195281
# min         0.098837
# 25%         0.461126
# 50%         0.632867
# 75%         0.771980
# max         0.974048
# Name: COMPL_RPY_5YR_RT_numeric, dtype: float64

# %%
df["MEDIAN_HH_INC_numeric"].describe()
# Out:
# count      4904.000000
# mean      57892.366829
# std       13063.193287
# min       15429.010000
# 25%       49516.995000
# 50%       57634.320000
# 75%       66212.920000
# max      100870.750000
# Name: MEDIAN_HH_INC_numeric, dtype: float64

# %% [markdown]
# Numericca otkazgan 3ta datamizni umumiy harakterishtikalarni korib chiqdik

# %%
df["DEBT_MDN"].describe()
# Out:
# count                  6681
# unique                 1926
# top       PrivacySuppressed
# freq                    917
# Name: DEBT_MDN, dtype: object

# %% [markdown]
# Oldingi holatda bizda "PrivacySuppressed" degan str type ham mavjud ekan. Hozir ularni korib chiqamiz

# %%
df[df["DEBT_MDN_numeric"].isnull()]["DEBT_MDN"]
# Out:
# 17      PrivacySuppressed
# 19      PrivacySuppressed
# 21      PrivacySuppressed
# 25      PrivacySuppressed
# 27      PrivacySuppressed
#               ...
# 6618    PrivacySuppressed
# 6619    PrivacySuppressed
# 6643    PrivacySuppressed
# 6694    PrivacySuppressed
# 6695    PrivacySuppressed
# Name: DEBT_MDN, Length: 938, dtype: object

# %% [markdown]
# ["DEBT_MDN","COMPL_RPY_5YR_RT","MEDIAN_HH_INC"]

# %%
df["COMPL_RPY_5YR_RT"].describe()
# Out:
# count                  5708
# unique                 2761
# top       PrivacySuppressed
# freq                   1257
# Name: COMPL_RPY_5YR_RT, dtype: object

# %%
df[df["COMPL_RPY_5YR_RT_numeric"].isnull()]["COMPL_RPY_5YR_RT"]
# Out:
# 10      PrivacySuppressed
# 12      PrivacySuppressed
# 14      PrivacySuppressed
# 17                    NaN
# 18                    NaN
#               ...
# 6696                  NaN
# 6697                  NaN
# 6699                  NaN
# 6700                  NaN
# 6701                  NaN
# Name: COMPL_RPY_5YR_RT, Length: 2251, dtype: object

# %% [markdown]
# Bunda bizda PrivacySuppressed dan tashqari NaN lar ham mavjud ekan

# %%
df["MEDIAN_HH_INC"].describe()
# Out:
# count                  4993
# unique                 4352
# top       PrivacySuppressed
# freq                     89
# Name: MEDIAN_HH_INC, dtype: object

# %%
df[df["MEDIAN_HH_INC_numeric"].isnull()]["MEDIAN_HH_INC"]
# Out:
# 18      NaN
# 46      NaN
# 59      NaN
# 70      NaN
# 71      NaN
#        ...
# 6697    NaN
# 6698    NaN
# 6699    NaN
# 6700    NaN
# 6701    NaN
# Name: MEDIAN_HH_INC, Length: 1798, dtype: object

# %% [markdown]
# Bunda bizda faqat NaN lar 1798 ta mavjud ekan

# %%
df[df["DEBT_MDN_numeric"].isnull()]["DEBT_MDN"].unique()
# Out:
# array(['PrivacySuppressed', nan], dtype=object)

# %%
df[df["COMPL_RPY_5YR_RT_numeric"].isnull()]["COMPL_RPY_5YR_RT"].unique()
# Out:
# array(['PrivacySuppressed', nan], dtype=object)

# %%
df[df["MEDIAN_HH_INC_numeric"].isnull()]["MEDIAN_HH_INC"].unique()
# Out:
# array([nan, 'PrivacySuppressed'], dtype=object)

# %% [markdown]
# Deyarlik barchasida nan va PrivacySuppressed lar mavjud ekan. Keling shularni tozalashga harakat qilib koramiz

# %%
df["DEBT_MDN_numeric"].describe()
# Out:
# count     5764.000000
# mean     11363.965389
# std       5517.351823
# min       1109.500000
# 25%       7248.000000
# 50%       9500.000000
# 75%      14750.000000
# max      36923.000000
# Name: DEBT_MDN_numeric, dtype: float64

# %%
df["COMPL_RPY_5YR_RT_numeric"].describe()
# Out:
# count    4451.000000
# mean        0.614998
# std         0.195281
# min         0.098837
# 25%         0.461126
# 50%         0.632867
# 75%         0.771980
# max         0.974048
# Name: COMPL_RPY_5YR_RT_numeric, dtype: float64

# %%
df["MEDIAN_HH_INC_numeric"].describe()
# Out:
# count      4904.000000
# mean      57892.366829
# std       13063.193287
# min       15429.010000
# 25%       49516.995000
# 50%       57634.320000
# 75%       66212.920000
# max      100870.750000
# Name: MEDIAN_HH_INC_numeric, dtype: float64

# %%
df.groupby(by=["REGION","Ownership"])["DEBT_MDN_numeric"].agg(["count",'mean',"median"])
# Out:
#                            count          mean   median
# REGION Ownership
# 0      Public                  1   5500.000000   5500.0
# 1      Private for-profit    116   8932.254310   8550.0
#        Private non-profit    141  18514.000000  18939.0
#        Public                 96  11162.000000   9500.0
# 2      Private for-profit    371   9285.692722   9000.0
#        Private non-profit    290  17787.443103  19050.0
#        Public                278  11239.041367   9285.5
# 3      Private for-profit    359   9741.203343   9500.0
#        Private non-profit    254  17715.192913  18739.0
#        Public                269   9647.446097   6754.0
# 4      Private for-profit    170  10787.297059  10051.5
#        Private non-profit    153  16068.251634  16312.0
#        Public                187   9458.000000   8750.5
# 5      Private for-profit    666   9593.185435   9500.0
#        Private non-profit    341  15162.159824  14726.0
# ...

# %%
df.groupby(by=["REGION","Ownership"])["COMPL_RPY_5YR_RT_numeric"].agg(["count",'mean',"median"])
# Out:
#                            count      mean    median
# REGION Ownership
# 0      Public                  0       NaN       NaN
# 1      Private for-profit     82  0.483915  0.445158
#        Private non-profit    114  0.841444  0.861386
#        Public                 80  0.785518  0.789640
# 2      Private for-profit    277  0.477198  0.463014
#        Private non-profit    241  0.794584  0.826484
#        Public                241  0.710838  0.704545
# 3      Private for-profit    239  0.455290  0.450980
#        Private non-profit    207  0.755842  0.804878
#        Public                238  0.693181  0.707352
# 4      Private for-profit    118  0.544825  0.580369
#        Private non-profit    127  0.820187  0.838095
#        Public                166  0.755907  0.767742
# 5      Private for-profit    498  0.423763  0.415064
#        Private non-profit    288  0.659756  0.717137
#        Public                326  0.648740  0.658231
# ...

# %%
df.groupby(by=["REGION","Ownership"])["MEDIAN_HH_INC_numeric"].agg(["count",'mean',"median"])
# Out:
#                            count          mean     median
# REGION Ownership
# 0      Public                  1  76831.570000  76831.570
# 1      Private for-profit     85  64185.141529  64889.670
#        Private non-profit    134  74134.389254  75915.830
#        Public                 96  64985.546771  65332.410
# 2      Private for-profit    242  59398.184050  57362.635
#        Private non-profit    327  65440.383761  64312.900
#        Public                267  61412.821348  60121.660
# 3      Private for-profit    200  59500.259800  58270.210
#        Private non-profit    237  64518.749114  63695.210
#        Public                262  58155.774504  58122.595
# 4      Private for-profit    110  55012.325455  53669.455
#        Private non-profit    164  59979.352256  60280.735
#        Public                194  53134.719691  51607.975
# 5      Private for-profit    335  52939.316746  51582.770
#        Private non-profit    322  57722.950466  56984.700
# ...

# %% [markdown]
# Hozir biz numric otkazgan qatorlarimizi regionlar va ownershiplar boyicha gruppalab meadian va meanlarini olib kordik

# %% [markdown]
# Har bitta qatordagi nullar orniga mean va medianlarni qoyyib chiqamiz

# %% [markdown]
# ["DEBT_MDN","COMPL_RPY_5YR_RT","MEDIAN_HH_INC"]

# %%
df["DEBT_MDN_FILLNA_MEAN"] = (
    df
    .groupby(by=["REGION","Ownership"])["DEBT_MDN_numeric"]
    .transform(lambda x: x.fillna(x.mean()))
)

# %%
df["DEBT_MDN_FILLNA_MEAN"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["DEBT_MDN_FILLNA_MEAN"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6702 entries, 0 to 6701
# Series name: DEBT_MDN_FILLNA_MEAN
# Non-Null Count  Dtype
# --------------  -----
# 6702 non-null   float64
# dtypes: float64(1)
# memory usage: 52.5 KB

# %% [markdown]
# Korib turganizdek NaN yoki str typelar qolmadi

# %%
df["COMPL_RPY_5YR_RT_FILLNA_MEAN"] = (
    df
    .groupby(by=["REGION","Ownership"])["COMPL_RPY_5YR_RT_numeric"]
    .transform(lambda x: x.fillna(x.mean()))
)

# %%
df["COMPL_RPY_5YR_RT_FILLNA_MEAN"].isnull().sum()
# Out:
# np.int64(1)

# %%
df["COMPL_RPY_5YR_RT_FILLNA_MEAN"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6702 entries, 0 to 6701
# Series name: COMPL_RPY_5YR_RT_FILLNA_MEAN
# Non-Null Count  Dtype
# --------------  -----
# 6701 non-null   float64
# dtypes: float64(1)
# memory usage: 52.5 KB

# %%
df["MEDIAN_HH_INC_FILLNA_MEAN"] = (
    df
    .groupby(by=["REGION","Ownership"])["MEDIAN_HH_INC_numeric"]
    .transform(lambda x: x.fillna(x.mean()))
)

# %%
df["MEDIAN_HH_INC_FILLNA_MEAN"].isnull().sum()
# Out:
# np.int64(0)

# %%
df["MEDIAN_HH_INC_FILLNA_MEAN"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 6702 entries, 0 to 6701
# Series name: MEDIAN_HH_INC_FILLNA_MEAN
# Non-Null Count  Dtype
# --------------  -----
# 6702 non-null   float64
# dtypes: float64(1)
# memory usage: 52.5 KB

# %% [markdown]
# Bu yuqorida korib turganizdek object typeda qolib ketgan 3 ta datani numeric ca otkazdik va tozalab oldik meanlar bilan toldirib
# Endi ular ustida grafiklar chizib koramiz

# %% [markdown]
# ["DEBT_MDN","COMPL_RPY_5YR_RT","MEDIAN_HH_INC"]

# %%
df["DEBT_MDN_numeric"].hist(bins=30)  
plt.xlabel('DEBT_MDN_numeric')
plt.ylabel('Frequency')
plt.title('Histogram of DEBT_MDN_numeric')
plt.show()

# %%
df["DEBT_MDN_FILLNA_MEAN"].hist(bins=30)  
plt.xlabel('DEBT_MDN_FILLNA_MEAN')
plt.ylabel('Frequency')
plt.title('Histogram of DEBT_MDN_FILLNA_MEAN')
plt.show()

# %%
plt.hist(df["DEBT_MDN_numeric"], bins=30, alpha=0.5, color='red', label='DEBT_MDN_numeric')

plt.hist(df["DEBT_MDN_FILLNA_MEAN"], bins=30, alpha=0.5, color='green', label='DEBT_MDN_FILLNA_MEAN')

plt.xlabel('Income')
plt.ylabel('Frequency')
plt.title('Histogram of DEBT_MDN_numeric and DEBT_MDN_FILLNA_MEAN')

plt.legend()

plt.show()

# %%
df["COMPL_RPY_5YR_RT_numeric"].hist(bins=30)  
plt.xlabel('COMPL_RPY_5YR_RT_numeric')
plt.ylabel('Frequency')
plt.title('Histogram of COMPL_RPY_5YR_RT_numeric')
plt.show()

# %%
df["COMPL_RPY_5YR_RT_FILLNA_MEAN"].hist(bins=30)  
plt.xlabel('COMPL_RPY_5YR_RT_FILLNA_MEAN')
plt.ylabel('Frequency')
plt.title('Histogram of COMPL_RPY_5YR_RT_FILLNA_MEAN')
plt.show()

# %%
plt.hist(df["COMPL_RPY_5YR_RT_numeric"], bins=30, alpha=0.5, color='red', label='COMPL_RPY_5YR_RT_numeric')

plt.hist(df["COMPL_RPY_5YR_RT_FILLNA_MEAN"], bins=30, alpha=0.5, color='green', label='COMPL_RPY_5YR_RT_FILLNA_MEAN')

plt.xlabel('Income')
plt.ylabel('Frequency')
plt.title('Histogram of COMPL_RPY_5YR_RT_numeric and COMPL_RPY_5YR_RT_FILLNA_MEAN')

plt.legend()

plt.show()

# %%
df["MEDIAN_HH_INC_numeric"].hist(bins=30)  
plt.xlabel('MEDIAN_HH_INC_numeric')
plt.ylabel('Frequency')
plt.title('Histogram of MEDIAN_HH_INC_numeric')
plt.show()

# %%
df["MEDIAN_HH_INC_FILLNA_MEAN"].hist(bins=30)  
plt.xlabel('MEDIAN_HH_INC_FILLNA_MEAN')
plt.ylabel('Frequency')
plt.title('Histogram of MEDIAN_HH_INC_FILLNA_MEAN')
plt.show()

# %%
plt.hist(df["MEDIAN_HH_INC_numeric"], bins=30, alpha=0.5, color='red', label='MEDIAN_HH_INC_numeric')

plt.hist(df["MEDIAN_HH_INC_FILLNA_MEAN"], bins=30, alpha=0.5, color='green', label='MEDIAN_HH_INC_FILLNA_MEAN')

plt.xlabel('Income')
plt.ylabel('Frequency')
plt.title('Histogram of MEDIAN_HH_INC_numeric and MEDIAN_HH_INC_FILLNA_MEAN')

plt.legend()

plt.show()

# %%
df
# Out:
#                                                  INSTNM    OPEID  REGION  \
# 0                              Alabama A & M University   100200       5
# 1                   University of Alabama at Birmingham   105200       5
# 2                                    Amridge University  2503400       5
# 3                   University of Alabama in Huntsville   105500       5
# 4                              Alabama State University   100500       5
# ...                                                 ...      ...     ...
# 6697          SAE Institute of Technology San Francisco  4205801       8
# 6698                  Rasmussen College - Overland Park   869423       4
# 6699  National Personal Training Institute of Cleveland  4220901       3
# 6700  Bay Area Medical Academy - San Jose Satellite ...  4223701       8
# 6701                        High Desert Medical College  4228101       8
#
#       SAT_AVG_ALL  PCTPELL  PCTFLOAN  ADM_RATE_ALL       UG  AVGFACSAL  \
# ...

# %%
g = sns.FacetGrid(df,col="HIGHDEG")
g.map(sns.boxplot, "Tuition")
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:718: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
g = sns.FacetGrid(df,col="REGION")
g.map(plt.scatter, "Tuition","DEBT_MDN_FILLNA_MEAN")

# %%
g = sns.FacetGrid(df,col="REGION")
g.map(plt.scatter, "Tuition","COMPL_RPY_5YR_RT_FILLNA_MEAN")

# %%
g = sns.FacetGrid(df,col="REGION")
g.map(plt.scatter, "Tuition","MEDIAN_HH_INC_FILLNA_MEAN")

# %% [markdown]
# Tozalangan datalar boyicha facedridlarini korib chiqdik

# %%
g = sns.PairGrid(df,vars=["DEBT_MDN_FILLNA_MEAN","COMPL_RPY_5YR_RT_FILLNA_MEAN"])
g = g.map(sns.scatterplot)

# %%
g = sns.PairGrid(df,vars=["COMPL_RPY_5YR_RT_FILLNA_MEAN","MEDIAN_HH_INC_FILLNA_MEAN"])
g = g.map(sns.scatterplot)

# %%
g = sns.PairGrid(df,vars=["MEDIAN_HH_INC_FILLNA_MEAN","DEBT_MDN_FILLNA_MEAN"])
g = g.map(sns.scatterplot)

# %%
g = sns.PairGrid(df,vars=["DEBT_MDN_FILLNA_MEAN","COMPL_RPY_5YR_RT_FILLNA_MEAN"])
g = g.map_diag(sns.histplot)
g = g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(df,vars=["COMPL_RPY_5YR_RT_FILLNA_MEAN","MEDIAN_HH_INC_FILLNA_MEAN"])
g = g.map_diag(sns.histplot)
g = g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(df,vars=["MEDIAN_HH_INC_FILLNA_MEAN","DEBT_MDN_FILLNA_MEAN"])
g = g.map_diag(sns.histplot)
g = g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(df,vars=["DEBT_MDN_FILLNA_MEAN","COMPL_RPY_5YR_RT_FILLNA_MEAN"])
g = g.map_diag(sns.boxplot)
g = g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(df,vars=["COMPL_RPY_5YR_RT_FILLNA_MEAN","MEDIAN_HH_INC_FILLNA_MEAN"])
g = g.map_diag(sns.boxplot)
g = g.map_offdiag(sns.scatterplot)

# %%
g = sns.PairGrid(df,vars=["MEDIAN_HH_INC_FILLNA_MEAN","DEBT_MDN_FILLNA_MEAN"])
g = g.map_diag(sns.boxplot)
g = g.map_offdiag(sns.scatterplot)

# %%
sns.pairplot(df,vars=["DEBT_MDN_FILLNA_MEAN","COMPL_RPY_5YR_RT_FILLNA_MEAN"], kind = "reg",diag_kind="hist")

# %%
sns.pairplot(df,vars=["COMPL_RPY_5YR_RT_FILLNA_MEAN","MEDIAN_HH_INC_FILLNA_MEAN"], kind = "reg",diag_kind="hist")

# %%
sns.pairplot(df,vars=["MEDIAN_HH_INC_FILLNA_MEAN","DEBT_MDN_FILLNA_MEAN"], kind = "reg",diag_kind="hist")

# %%
sns.pairplot(df.query("REGION<3"),vars=["DEBT_MDN_FILLNA_MEAN","COMPL_RPY_5YR_RT_FILLNA_MEAN"],hue="REGION",palette="husl",plot_kws={"alpha":0.5})

# %%
sns.pairplot(df.query("REGION<3"),vars=["COMPL_RPY_5YR_RT_FILLNA_MEAN","MEDIAN_HH_INC_FILLNA_MEAN"],hue="REGION",palette="husl",plot_kws={"alpha":0.5})

# %%
sns.pairplot(df.query("REGION<3"),vars=["MEDIAN_HH_INC_FILLNA_MEAN","DEBT_MDN_FILLNA_MEAN"],hue="REGION",palette="husl",plot_kws={"alpha":0.5})

# %%
g = sns.JointGrid(df,x="MEDIAN_HH_INC_FILLNA_MEAN",y="DEBT_MDN_FILLNA_MEAN")
g.plot(sns.regplot, sns.histplot)

# %%
g = sns.JointGrid(df,x="MEDIAN_HH_INC_FILLNA_MEAN",y="DEBT_MDN_FILLNA_MEAN")
g = g.plot_joint(sns.kdeplot)
g = g.plot_marginals(sns.kdeplot,shade=True)
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:1883: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, ax=self.ax_marg_x, **kwargs)
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:1889: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(y=self.y, ax=self.ax_marg_y, **kwargs)

# %%
sns.jointplot(df,x="Tuition",y="MEDIAN_HH_INC_FILLNA_MEAN",kind="hex")

# %%
sns.jointplot(df,x="Tuition",y="DEBT_MDN_FILLNA_MEAN",kind="hex")

# %%
sns.jointplot(df,x="Tuition",y="COMPL_RPY_5YR_RT_FILLNA_MEAN",kind="hex")
