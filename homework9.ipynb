# %%
import pandas as pd

# %%
import matplotlib.pylab as plt

# %%
import seaborn as sns

# %%
Obesity = pd.read_csv("Obesity Levels.csv")
Obesity
# Out:
#             Age  Gender    Height      Weight        CALC FAVC  FCVC  NCP  \
# 0     21.000000  Female  1.620000   64.000000          no   no   2.0  3.0
# 1     21.000000  Female  1.520000   56.000000   Sometimes   no   3.0  3.0
# 2     23.000000    Male  1.800000   77.000000  Frequently   no   2.0  3.0
# 3     27.000000    Male  1.800000   87.000000  Frequently   no   3.0  3.0
# 4     22.000000    Male  1.780000   89.800000   Sometimes   no   2.0  1.0
# ...         ...     ...       ...         ...         ...  ...   ...  ...
# 2106  20.976842  Female  1.710730  131.408528   Sometimes  yes   3.0  3.0
# 2107  21.982942  Female  1.748584  133.742943   Sometimes  yes   3.0  3.0
# 2108  22.524036  Female  1.752206  133.689352   Sometimes  yes   3.0  3.0
# 2109  24.361936  Female  1.739450  133.346641   Sometimes  yes   3.0  3.0
# 2110  23.664709  Female  1.738836  133.472641   Sometimes  yes   3.0  3.0
#
#       SCC SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# ...

# %% [markdown]
# Umumiy surveydagi insonlar sonini yoshlar taqsimoti boyicha korish

# %%
a = Obesity["Age"].value_counts()
print(a)
# Out:
# Age
# 18.000000    128
# 26.000000    101
# 21.000000     96
# 23.000000     89
# 19.000000     59
#             ...
# 21.568951      1
# 23.647935      1
# 24.196367      1
# 24.284833      1
# 23.761970      1
# Name: count, Length: 1402, dtype: int64

# %% [markdown]
# Surveydagi ayol va erkaklarning qanchalik public transportdan foydalanish darajasi

# %%
sns.catplot(x="MTRANS", y="Age", data=Obesity, hue="Gender",kind="point") 

plt.xticks(rotation=30)

plt.show()

# %% [markdown]
# Endi shu yuqorida qilganimizga style set qilib koramiz set_style bilan

# %%
sns.set_style("whitegrid") 

sns.catplot(x="MTRANS", y="Age", data=Obesity, hue="Gender",kind="point") 

plt.xticks(rotation=30)

plt.show()

# %%
sns.set_style("ticks") 


sns.catplot(x="MTRANS", y="Age", data=Obesity, hue="Gender",kind="point") 

plt.xticks(rotation=30)

plt.show()

# %% [markdown]
# Endi shuni catplot bilan faqat bitta ozgaruvchi bilan kiritib koramiz

# %%
sns.set_style("whitegrid") 


sns.catplot(x="MTRANS", data=Obesity, hue="Gender",kind="count") 

plt.xticks(rotation=30)

plt.show()

# %% [markdown]
# Bu jadval ayollar va erkaklarning public transportlarni qaysi birini qancha foydalanishini ifodalaab keladi

# %%
sns.set_style("whitegrid")
sns.set_context("notebook")


sns.catplot(x="MTRANS", y="Age", data=Obesity, hue="Gender",kind="point") 

plt.xticks(rotation=30) 

plt.grid(True)

plt.show()

# %% [markdown]
# BUnda biz orqa dizaynga set_context methodi orqali kataklarni qoshib oldik

# %% [markdown]
# CATPLOT chizib koramiz

# %%
plot = sns.catplot(x="MTRANS", y="Age", data=Obesity, hue="Gender", kind="box")

plt.xticks(rotation=45)

plot.figure.suptitle("New Title")

plt.tight_layout()

plt.show()

# %% [markdown]
# Xulosa qilib aytsak, har bir turda deyarlik outlier mavjud. Eng kop foydalanuvchilar ayollar va erkaklar uchun ham avtomobil togri kelmoqda

# %%
sns.set_style("whitegrid")
sns.set_context("notebook")
sns.set_palette(["blue", "red"])

plot = sns.catplot(x="MTRANS", y="Age", data=Obesity, hue="Gender", kind="point", col = "family_history_with_overweight")

for ax in plot.axes.flat:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
    


plot.figure.suptitle("Survey about ovearweight")

plt.tight_layout()

plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1800\2165935101.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
# C:\Users\user\AppData\Local\Temp\ipykernel_1800\2165935101.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30)

# %% [markdown]
# bunda semizlar historysini korsak ham korinib turibdiki, semizlar kam bolgan oilalar doimiy ravishda public transportlaridan kam foydalanib kelishgan.

# %% [markdown]
# Endi xuddi shu natijani chekuvchi va chekmaydiganlar uchun koramiz

# %%
sns.set_style("whitegrid")
sns.set_context("notebook")
sns.set_palette(["blue", "red"])

plot = sns.catplot(x="MTRANS", y="Age", data=Obesity, hue="Gender", kind="point", col = "SMOKE")

for ax in plot.axes.flat:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
    


plot.figure.suptitle("Survey about ovearweight")

plt.tight_layout()

plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1800\1364857293.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30)
# C:\Users\user\AppData\Local\Temp\ipykernel_1800\1364857293.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=30)

# %% [markdown]
# Diagrammalarni endi oddiy matplotlib va pandas orqali koramiz chizib

# %%
import matplotlib.pyplot as plt 
import pandas as pd  

fig, ax = plt.subplots() 
ax.hist(Obesity['Weight'])
# Out:
# (array([243., 286., 336., 427., 273., 291., 156.,  74.,  21.,   4.]),
#  array([ 39. ,  52.4,  65.8,  79.2,  92.6, 106. , 119.4, 132.8, 146.2,
#         159.6, 173. ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots() 

a = ax.hist(Obesity['Height']) 
print(a)
# Out:
# (array([ 24., 112., 220., 412., 387., 425., 313., 167.,  43.,   8.]), array([1.45 , 1.503, 1.556, 1.609, 1.662, 1.715, 1.768, 1.821, 1.874,
#        1.927, 1.98 ]), <BarContainer object of 10 artists>)

# %%
sns.displot(Obesity["Height"], kind="kde")

# %%
sns.displot(Obesity["Height"], kde=True, bins=10)

# %%
sns.displot(Obesity["Weight"], kde=True, bins=10)

# %%
sns.displot(Obesity["Weight"], kind="ecdf" )

# %%
sns.displot(Obesity["Height"], kind="ecdf" )

# %% [markdown]
# Endi regression liner plot chizib koramiz

# %%
sns.regplot(data=Obesity,x="Height", y="Weight")
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %% [markdown]
# Xulosa qilib aytsak boy va vazn ortasidagi eng yaxshi bogliqlikni ifodalab beruvchi chiziqlik tenglama shu korinishda otar ekan
