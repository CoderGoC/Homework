# %%
import pandas as pd

# %%
import matplotlib.pylab as plt

# %%
import seaborn as sns

# %% [markdown]
# # Ishlamoqchi bolgan data frame ni kiritib olamiz

# %%
Obesity = pd.read_csv("Obesity Levels.csv")
Obesity
# Out:
#             Age  Gender    Height      Weight        CALC FAVC  FCVC  NCP  \
# 0     21.000000  Female  1.620000   64.000000          no   no   2.0  3.0
# 1     21.000000  Female  1.520000   56.000000   Sometimes   no   3.0  3.0
# 2     23.000000    Male  1.800000   77.000000  Frequently   no   2.0  3.0
# 3     27.000000    Male  1.800000   87.000000  Frequently   no   3.0  3.0
# 4     22.000000    Male  1.780000   89.800000   Sometimes   no   2.0  1.0
# ...         ...     ...       ...         ...         ...  ...   ...  ...
# 2106  20.976842  Female  1.710730  131.408528   Sometimes  yes   3.0  3.0
# 2107  21.982942  Female  1.748584  133.742943   Sometimes  yes   3.0  3.0
# 2108  22.524036  Female  1.752206  133.689352   Sometimes  yes   3.0  3.0
# 2109  24.361936  Female  1.739450  133.346641   Sometimes  yes   3.0  3.0
# 2110  23.664709  Female  1.738836  133.472641   Sometimes  yes   3.0  3.0
#
#       SCC SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# ...

# %% [markdown]
# ### Jinslar ortasida vaznlarning taqsimlanishi

# %%
sns.stripplot(data=Obesity, y="Gender",x="Weight",jitter=True)
# Out:
# <Axes: xlabel='Weight', ylabel='Gender'>

# %% [markdown]
# Xulosa qilib aytsak, Erkaklar o'rtasida vaznlar zichligi nisbatan zichroq ayollarga qaraganda. Ayollarda tarqoqroq joylashgan ekan. Va erkaklarda bitta outlier ham mavjud ekan.

# %% [markdown]
# ### Jinslar ortasida boylarning taqsimlanishi

# %%
sns.stripplot(data=Obesity, y="Gender",x="Height",jitter=True)
# Out:
# <Axes: xlabel='Height', ylabel='Gender'>

# %% [markdown]
# Bundan korinadiki ayollarning ortacha boy sochilishi erkaklarnikiga qaraganda pastroq ekan. Ayollarning boylari 1,5 va 1,8 orasida bolsa erkaklarda biroz kattaroq bu korsatkich yani 1,6 dan 2,0 gachani tashkil etmoqda

# %% [markdown]
# ### Semiz odamlarning jamoat transportidan foydalanish taqsimoti

# %%
sns.stripplot(data=Obesity, y="MTRANS",x="Weight",jitter=True)
# Out:
# <Axes: xlabel='Weight', ylabel='MTRANS'>

# %% [markdown]
# Bundan shuni xulosa qilsak boladiki, jismoniy harakat yordamida boshqariladigan transport vositalarni va piyodalar orasida nisbatan semizlik darajasi pastroq ekan

# %%
sns.swarmplot(data=Obesity, y="Gender", x="Height",palette="viridis")
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21996\960222617.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=Obesity, y="Gender", x="Height",palette="viridis")
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 11.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 16.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Height', ylabel='Gender'>
# ...

# %%
sns.swarmplot(data=Obesity, y="Gender", x="Height", palette=["#FF6347", "#4682B4"])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21996\1372279541.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=Obesity, y="Gender", x="Height", palette=["#FF6347", "#4682B4"])
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 11.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 16.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='Height', ylabel='Gender'>
# ...

# %% [markdown]
# ### Jamoat transportlaridan yosh ortasida foydalanish miqdorini taqsimlanishi

# %%
sns.boxplot(data=Obesity, y="MTRANS",x="Age")
# Out:
# <Axes: xlabel='Age', ylabel='MTRANS'>

# %% [markdown]
# Bunda ham jismoniy harakat vositasida boshqariladigan transport va piyodalar ortasida yosh foydalanuvchi taqsimoti nisbatan yaxshiroq bolsa jamoat transporti va shaxsiy avtomobiledan foydalanganlar ortasida kop semizlar bolmoqda va hatto outlier ham ularda ancha kop ekan

# %% [markdown]
# ### Sogloq ovqatlanishning yoshlar ortasida taqsimotini korsak boladi bunda

# %%
sns.boxplot(data=Obesity, y="CALC",x="Age")
# Out:
# <Axes: xlabel='Age', ylabel='CALC'>

# %% [markdown]
# Nisbatan surveydagi kop yoshlar soglom ovqatlanishga harakat qilar ekan.
# Lekin doimiy soglom ovqatlanish routine ga faqat 21 22 yoshlar ortasida amal qilish kopligini korish mumkin

# %% [markdown]
# ### Quyida ularni qanday std da tarqalishi

# %%
sns.violinplot(data=Obesity, y="CALC",x="Age")
# Out:
# <Axes: xlabel='Age', ylabel='CALC'>

# %%
sns.violinplot(data=Obesity, y="Gender",x="Weight")
# Out:
# <Axes: xlabel='Weight', ylabel='Gender'>

# %%
sns.boxenplot(data=Obesity, y="Gender", x="Weight", palette=["#FF6347", "#4682B4"])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21996\1465762297.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(data=Obesity, y="Gender", x="Weight", palette=["#FF6347", "#4682B4"])
# <Axes: xlabel='Weight', ylabel='Gender'>

# %% [markdown]
# ### Barplot yordamida taqsimotlarni korish

# %%
sns.barplot(data=Obesity, y="MTRANS", x="Weight", hue="Gender", palette=["#FF6347", "#4682B4"])
# Out:
# <Axes: xlabel='Weight', ylabel='MTRANS'>

# %% [markdown]
# Bundan korinadiki erkaklar ayollarga nisbatan ancha faol ekan qoshtirnoq ichida. Ayollarda semizlik darajasi ancha past ekan. Hatto erkaklar velosipeddan foydalansa ham semizlik yuqori bolib chiqmoqda

# %% [markdown]
# ### Soglom ovqatlanish jinslar ortasida taqsimoti

# %%
sns.barplot(data=Obesity, y="CALC", x="Weight", hue="Gender", palette=["#FF6347", "#4682B4"])
# Out:
# <Axes: xlabel='Weight', ylabel='CALC'>

# %% [markdown]
# Bunda ham huddi yuqoridagi holatni korish mumkin yani erkaklar nisbatan qoshtirmoq ichida faol ekanlar soglom ovqatlanishda. Yani ular doimiy va vaqtincha soglom ovqatlansa ham semizlik darajasi yuqori

# %% [markdown]
# ### Quyida ushbu qilinganlarni pointlar va trendlar bilann korish mumkin

# %%
sns.pointplot(data=Obesity, y="MTRANS", x="Age", hue="Gender", palette=["#FF6347", "#4682B4"])
# Out:
# <Axes: xlabel='Age', ylabel='MTRANS'>

# %%
sns.pointplot(data=Obesity, y="CALC", x="Age", hue="Gender")
# Out:
# <Axes: xlabel='Age', ylabel='CALC'>

# %% [markdown]
# ### Quyida ularning miqdorini sanaganmiz countplot yordamida

# %%
sns.countplot(data=Obesity, y="MTRANS", hue="Gender")
# Out:
# <Axes: xlabel='count', ylabel='MTRANS'>

# %%
sns.countplot(data=Obesity, y="CALC", hue="Gender")
# Out:
# <Axes: xlabel='count', ylabel='CALC'>

# %%
sns.countplot(data=Obesity, y="SMOKE", hue="Gender")
# Out:
# <Axes: xlabel='count', ylabel='SMOKE'>

# %%
sns.regplot(data=Obesity, x="Age",y="Weight")
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.regplot(data=Obesity, x="Age",y="Weight",marker="+")
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.residplot(data=Obesity, x="Age",y="Weight")
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
sns.regplot(data=Obesity, x="Age",y="Height",marker="+")
# Out:
# <Axes: xlabel='Age', ylabel='Height'>

# %%
sns.residplot(data=Obesity, x="Age",y="Height")
# Out:
# <Axes: xlabel='Age', ylabel='Height'>

# %%
sns.regplot(data=Obesity, x='Weight', y='Age', order=2)
# Out:
# <Axes: xlabel='Weight', ylabel='Age'>

# %%
sns.regplot(data=Obesity, x='Weight', y='Height', order=2)
# Out:
# <Axes: xlabel='Weight', ylabel='Height'>

# %%
sns.regplot(data=Obesity, x='Weight', y='Age', order=3)
# Out:
# <Axes: xlabel='Weight', ylabel='Age'>

# %%
sns.regplot(data=Obesity, x='Weight', y='Height', order=3)
# Out:
# <Axes: xlabel='Weight', ylabel='Height'>

# %%
sns.regplot(data=Obesity, x='Weight', y='Age', order=4)
# Out:
# <Axes: xlabel='Weight', ylabel='Age'>

# %%
sns.regplot(data=Obesity, x='Weight', y='Height', order=4)
# Out:
# <Axes: xlabel='Weight', ylabel='Height'>

# %%
sns.regplot(data=Obesity, x='Weight', y='Age',x_jitter=.0, order=2)
# Out:
# <Axes: xlabel='Weight', ylabel='Age'>

# %%
sns.regplot(data=Obesity, x='Weight', y='Age',x_jitter=.1, order=2)
# Out:
# <Axes: xlabel='Weight', ylabel='Age'>

# %%
import numpy as np
sns.regplot(data=Obesity, x='Age', y='Weight',x_bins=5,x_estimator=np.mean, order=2)
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
import numpy as np
sns.regplot(data=Obesity, x='Age', y='Weight',x_bins=5,x_estimator=np.mean)
# Out:
# <Axes: xlabel='Age', ylabel='Weight'>

# %%
pd.crosstab(Obesity["Age"],Obesity["Gender"],values=Obesity["Weight"], aggfunc="mean").round(0)
# Out:
# Gender     Female  Male
# Age
# 14.000000     NaN  72.0
# 15.000000    86.0   NaN
# 16.000000    55.0  55.0
# 16.093234    65.0   NaN
# 16.129279    86.0   NaN
# ...           ...   ...
# 55.022494     NaN  80.0
# 55.137881     NaN  81.0
# 55.246250     NaN  80.0
# 56.000000     NaN  90.0
# 61.000000    66.0   NaN
#
# [1402 rows x 2 columns]

# %%
pd.crosstab(Obesity["Age"],Obesity["MTRANS"],values=Obesity["Weight"], aggfunc="mean").round(0)
# Out:
# MTRANS     Automobile  Bike  Motorbike  Public_Transportation  Walking
# Age
# 14.000000         NaN   NaN        NaN                    NaN     72.0
# 15.000000         NaN   NaN        NaN                    NaN     86.0
# 16.000000         NaN   NaN        NaN                   56.0     54.0
# 16.093234         NaN   NaN        NaN                   65.0      NaN
# 16.129279         NaN   NaN        NaN                   86.0      NaN
# ...               ...   ...        ...                    ...      ...
# 55.022494        80.0   NaN        NaN                    NaN      NaN
# 55.137881        81.0   NaN        NaN                    NaN      NaN
# 55.246250        80.0   NaN        NaN                    NaN      NaN
# 56.000000        90.0   NaN        NaN                    NaN      NaN
# 61.000000         NaN   NaN        NaN                   66.0      NaN
#
# [1402 rows x 5 columns]

# %%
pd.crosstab(Obesity["Age"],Obesity["CALC"],values=Obesity["Weight"], aggfunc="mean").round(0)
# Out:
# CALC       Always  Frequently  Sometimes    no
# Age
# 14.000000     NaN         NaN        NaN  72.0
# 15.000000     NaN         NaN        NaN  86.0
# 16.000000     NaN         NaN       55.0  56.0
# 16.093234     NaN         NaN        NaN  65.0
# 16.129279     NaN         NaN        NaN  86.0
# ...           ...         ...        ...   ...
# 55.022494     NaN         NaN        NaN  80.0
# 55.137881     NaN         NaN        NaN  81.0
# 55.246250     NaN         NaN        NaN  80.0
# 56.000000     NaN        90.0        NaN   NaN
# 61.000000     NaN        66.0        NaN   NaN
#
# [1402 rows x 4 columns]

# %% [markdown]
# ### Bog'liqlik darajalarini miqdorlarda ko'rish

# %%
heatmap_data = Obesity.pivot_table(index='Gender', columns='MTRANS', values='Weight', aggfunc='mean')


sns.heatmap(data=heatmap_data, annot=True, cmap='viridis')
# Out:
# <Axes: xlabel='MTRANS', ylabel='Gender'>

# %%
heatmap_data = Obesity.pivot_table(index='CALC', columns='MTRANS', values='Weight', aggfunc='mean')


sns.heatmap(data=heatmap_data, annot=True, cmap='viridis')
# Out:
# <Axes: xlabel='MTRANS', ylabel='CALC'>

# %% [markdown]
# ### Gruppalab olamiz

# %%
New_colms = Obesity.select_dtypes(include=['int64', 'float64', 'int32', 'float32']).columns.tolist()
New_colms
# Out:
# ['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']

# %% [markdown]
# ### HEATMAP

# %%
new_df = Obesity[New_colms].corr()
sns.heatmap(new_df, cmap="YlGnBu", annot=True, fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# Bunda biz barcha variables ortasidagi bogliqliklarni heatmap orqalik umumiy korishimiz mumkin
