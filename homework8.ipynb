# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
Obesity_level = pd.read_csv("Obesity Levels.csv")
Obesity_level
# Out:
#             Age  Gender    Height      Weight        CALC FAVC  FCVC  NCP  \
# 0     21.000000  Female  1.620000   64.000000          no   no   2.0  3.0
# 1     21.000000  Female  1.520000   56.000000   Sometimes   no   3.0  3.0
# 2     23.000000    Male  1.800000   77.000000  Frequently   no   2.0  3.0
# 3     27.000000    Male  1.800000   87.000000  Frequently   no   3.0  3.0
# 4     22.000000    Male  1.780000   89.800000   Sometimes   no   2.0  1.0
# ...         ...     ...       ...         ...         ...  ...   ...  ...
# 2106  20.976842  Female  1.710730  131.408528   Sometimes  yes   3.0  3.0
# 2107  21.982942  Female  1.748584  133.742943   Sometimes  yes   3.0  3.0
# 2108  22.524036  Female  1.752206  133.689352   Sometimes  yes   3.0  3.0
# 2109  24.361936  Female  1.739450  133.346641   Sometimes  yes   3.0  3.0
# 2110  23.664709  Female  1.738836  133.472641   Sometimes  yes   3.0  3.0
#
#       SCC SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# ...

# %% [markdown]
# Seaborn va pandas yordamida scatter plot chiqarish va taqqoslash
#
# Yosh va Vaznlar o'rtasidagi bogliqlik asosida scatter plot shakillantirib olamiz

# %%
sns.scatterplot(x="Weight", y="Age", data=Obesity_level)
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(Obesity_level["Weight"],Obesity_level["Age"])
ax.set_ylabel("Age")
ax.set_xlabel("Weight")
plt.show()

# %% [markdown]
# Title va ranglar qo'shib olamiz tushinish oson bolishi uchun

# %%
fig, ax = plt.subplots()
ax.scatter(Obesity_level["Weight"],Obesity_level["Age"],c=Obesity_level.index)
ax.set_ylabel("Yosh")
ax.set_xlabel("Vazn")
ax.set_title("Yosh va vazn o'rtasidagi bog'liqliklar")
plt.show()

# %% [markdown]
# Xulosa qilib aytsak, 20 yoshliklar ortasida barcha vazn turlari mavjud ekan va insonning o'rtacha vazni 80 kg atrofida tarqalganini ko'rishimiz ham mumkin

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(x="Weight",y="Age",data=Obesity_level, hue="Gender")

plt.show()

# %% [markdown]
# Bunda biz ayollar va erkaklar berilgan yosh oraligidagi semizlik darajalarini taqimlanishini ko'rishimiz mumkin.

# %% [markdown]
# Yuqoridagi scatterplot ga biroz rang berib koramiz malum bir codelar orqalik

# %%
hue_colors = {"Male":"#F0F00F",
              "Female": "#0FBB0F"}

sns.scatterplot(x="Weight",y="Age",data=Obesity_level, hue="Gender", palette=hue_colors)
# Out:
# <Axes: xlabel='Weight', ylabel='Age'>

# %% [markdown]
# Diagramma chiqib koramiz countplot yordaminida seaborn kutubxonasida
# Bunda semizlarning qancha spirtlik ichimliklar ichishini semizlik yoshlari orasidagi bogliqliklarni koramiz

# %%
sns.countplot(x="CALC",data=Obesity_level, hue="Gender")

plt.show()

# %% [markdown]
# Xulosa qilib aytadigan bolsak, semizlarning kop miqdori qaryib 1500 ga yaqini (Male and Female qoshib hisoblaganda) tez tez spirtli ichib turar ekan.

# %% [markdown]
# NOTE!  CALC : Feature, Categorical, " How often do you drink alcohol? "

# %% [markdown]
# Endi xuddi shu tekshiruvni checkuvchilar uchun amalga oshiramiz. Yani ushbu taqiqotga qamab olingan odamlarning chekishini koramiz

# %%
sns.countplot(x="SMOKE",data=Obesity_level,hue="Gender")
# Out:
# <Axes: xlabel='SMOKE', ylabel='count'>

# %% [markdown]
# Bundan korinib turibdiki, deyarlik semiz odamlarning 95 % ga yaqini chekmas ekanlar

# %% [markdown]
# Insonlar yoshi va vazni hamda yoshi va bo'ylari o'rtasidagi bog'liqliklarni ko'rish uchun (2,1) ko'rinishidagi scatter tashkil etish va xulosalar chiqarish
#
# Ushbu korsatkichlarni seaborn da ham amalga oshirish va solishtirish

# %%
fig, ax = plt.subplots(2,1)
ax[0].scatter(Obesity_level["Age"],Obesity_level["Weight"],c=Obesity_level.index)
ax[0].set_ylabel("Vazn")
ax[1].scatter(Obesity_level["Age"],Obesity_level["Height"],c=Obesity_level.index)
ax[1].set_ylabel("Bo'y")


plt.show()

# %% [markdown]
# Xulosa qilsak, 20 yoshlilar orasida barcha turdagi vaznlilar va bo'ylilar eng ko'pi ekan. 60 yoshdan kottalarda esa bitta o'rta boy va ozg'in inson borligini ko'rishimiz mumkin.

# %% [markdown]
# Endi xuddi shuni seabornda amalga oshirib koramiz

# %%
def change(num):
    x = list(str(int(num)))
    x[-1] = '0'
    return int(''.join(x))

Obesity_level['new_weight'] = Obesity_level['Weight'].agg(change)
Obesity_level['new_age'] = Obesity_level['Age'].agg(change)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3284\398404880.py:6: FutureWarning: using <function change at 0x000001DFBDF45620> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   Obesity_level['new_weight'] = Obesity_level['Weight'].agg(change)
# C:\Users\user\AppData\Local\Temp\ipykernel_3284\398404880.py:7: FutureWarning: using <function change at 0x000001DFBDF45620> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   Obesity_level['new_age'] = Obesity_level['Age'].agg(change)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


sns.relplot(x="Weight",y="FCVC",data=Obesity_level,kind="scatter",col="Gender")
sns.relplot(x="new_weight", y="Age", data=Obesity_level, kind="line",col="Gender")


plt.show()

# %% [markdown]
# NOTE !!!
#
# FCVC : Feature, Integer, " Do you usually eat vegetables in your meals? "

# %% [markdown]
# Vegetarian ayollar va erkaklarni korishimiz mumkin birinchi scatter plotda ularning soglom ovqatlanishi vaznga qanday tasir qilishini bogliqligini korsak,
# ikkinchisida esa ayollar va erkaklar ortasidagi o'rtacha vaznni korishimiz mumkin boladi

# %%
male_vazn = Obesity_level[Obesity_level["Gender"]=="Male"]["Weight"].mean()
print("Erkaklar vazn - ",male_vazn)
female_vazn = Obesity_level[Obesity_level["Gender"]=="Female"]["Weight"].mean()
print("Ayollar vazn - ",female_vazn)
# Out:
# Erkaklar vazn -  90.7694783445693
# Ayollar vazn -  82.30236417353788

# %% [markdown]
# Bunda ko'rishimiz mumkinki, erkaklar va ayollarning o'rtacha og'irligini.
#
# Erkaklar -  90.77 kg
#
# Ayollar -  82.30 kg

# %%
male_boy = Obesity_level[Obesity_level["Gender"]=="Male"]["Height"].mean()
print("Erkaklar boyi - ",male_boy)
female_boy = Obesity_level[Obesity_level["Gender"]=="Female"]["Height"].mean()
print("Ayollar boyi - ",female_boy)
# Out:
# Erkaklar boyi -  1.7586903352059924
# Ayollar boyi -  1.6432978092042185

# %% [markdown]
# Bunda ko'rishimiz mumkinki, erkaklar va ayollarning o'rtacha bo'ylarini .
#
# Erkaklar boyi -  1.76  sm
#
# Ayollar boyi -  1.64   sm

# %%
 
male_mean_height = Obesity_level[Obesity_level["Gender"] == "Male"]["Height"].mean()
female_mean_height = Obesity_level[Obesity_level["Gender"] == "Female"]["Height"].mean()
male_std_height = Obesity_level[Obesity_level["Gender"] == "Male"]["Height"].std()
female_std_height = Obesity_level[Obesity_level["Gender"] == "Female"]["Height"].std()

male_mean_weight = Obesity_level[Obesity_level["Gender"] == "Male"]["Weight"].mean()
female_mean_weight = Obesity_level[Obesity_level["Gender"] == "Female"]["Weight"].mean()
male_std_weight = Obesity_level[Obesity_level["Gender"] == "Male"]["Weight"].std()
female_std_weight = Obesity_level[Obesity_level["Gender"] == "Female"]["Weight"].std()

 
fig, ax = plt.subplots(2, 2, figsize=(10, 10))

 
ax[0, 0].scatter(Obesity_level[Obesity_level["Gender"]=="Male"]["Height"], Obesity_level[Obesity_level["Gender"]=="Male"]["Weight"], c='blue', label="Male")
ax[0, 0].set_xlabel("Bo'y")
ax[0, 0].set_ylabel("Vazn")
ax[0, 0].legend()

ax[0, 1].scatter(Obesity_level[Obesity_level["Gender"]=="Female"]["Height"], Obesity_level[Obesity_level["Gender"]=="Female"]["Weight"], c='orange', label="Female")
ax[0, 1].set_xlabel("Bo'y")
ax[0, 1].set_ylabel("Vazn")
ax[0, 1].legend()


ax[1, 0].bar("Male", height=male_mean_height, yerr=male_std_height, color='blue', label="Male")
ax[1, 0].bar("Female", height=female_mean_height, yerr=female_std_height, color='orange', label="Female")
ax[1, 0].set_ylabel("Bo'y")
ax[1, 0].legend()

ax[1, 1].bar("Male", height=male_mean_weight, yerr=male_std_weight, color='blue', label="Male")
ax[1, 1].bar("Female", height=female_mean_weight, yerr=female_std_weight, color='orange', label="Female")
ax[1, 1].set_ylabel("Vazn")
ax[1, 1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Bunda biz Ayollar va erkaklarning boyi va vazni ortasidagi bogliqliklarni hamda bar graph orqali ularni alohida alohida boy va vaznlarini std larini ham korib chiqdik.

# %% [markdown]
# ## Yoshning boy va vaznlari ortasidagi bogliqliklarni korish. Buni biz ayollar va erkaklar uchun qilamiz.

# %%
def change(num):
    x = list(str(int(num)))
    x[-1] = '0'
    return int(''.join(x))

Obesity_level['new_weight'] = Obesity_level['Weight'].agg(change)
Obesity_level['new_age'] = Obesity_level['Age'].agg(change)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3284\398404880.py:6: FutureWarning: using <function change at 0x000001DFBB928D60> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   Obesity_level['new_weight'] = Obesity_level['Weight'].agg(change)
# C:\Users\user\AppData\Local\Temp\ipykernel_3284\398404880.py:7: FutureWarning: using <function change at 0x000001DFBB928D60> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   Obesity_level['new_age'] = Obesity_level['Age'].agg(change)

# %%
import matplotlib.pyplot as plt
import seaborn as sns




plt.figure(figsize=(19, 6))
sns.lineplot(x="new_weight", y="Age", data=Obesity_level)


plt.xlabel("Vazn")
plt.ylabel("Yosh")
plt.title("Or'tacha yosh bilan vazn bog'liqligi")


plt.show()

# %%
 


ortacha = Obesity_level.groupby("new_age")[["new_weight"]].mean().reset_index()


plt.figure(figsize=(12, 8))
sns.lineplot(x="new_age", y="new_weight", data=ortacha)


plt.xlabel("Yosh")
plt.ylabel("Vazn")
plt.title("Or'tacha Vazn bilan yosh bog'liqligi")


plt.show()

# %%
 




plt.figure(figsize=(12, 8))
sns.lineplot(x="new_weight", y="Age", data=Obesity_level, hue="Gender")


plt.xlabel("Vazn")
plt.ylabel("Yosh")
plt.title("Or'tacha yosh bilan vazn bog'liqligi")


plt.show()

# %% [markdown]
# Xulosa qilib aytsak, erkaklarda og'ir vazin 22 va 30 yosh orasida taqsimlangan bir paytda bu korsatkich ayollar uchun 18-22 yoshni tashkil etmoqda

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x="Gender",data = Obesity_level )
plt.show()

# %% [markdown]
# Bunda biz umumiy sorovda ishtirok etkan barcha ayollar va erkaklar sonini korishimiz mumkin diagramma shaklida

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.catplot(x="Gender",y="Weight",data = Obesity_level, kind="bar" )
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.catplot(x="Gender",y="Height",data = Obesity_level, kind="bar" )
plt.show()

# %% [markdown]
# yuqoridagi 2ta barplotda ham erkaklar va ayolalrning ortacha boy va vaznlarini korishimiz mumkin.
#
# Bunda ikkovida ham erkaklarning nisbatan ustunligini korishimiz mumkin

# %% [markdown]
# Outlierlar bormi yoki yoqmi ?

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.catplot(x="Gender",y="Weight",data = Obesity_level, kind="box" )
plt.show()

# %% [markdown]
# Vazn boyicha koradigan bolsak, ekaklarda bitta outlier borligini korish mumkin. Lekin ayollarning max va min qiymatlari erkaklarnikiga qaraganda kotta va kichikroq. Lekin orta qiymat erkaklarda koproq va uning atrofida barcha kop qiymatlar toplangan bu degani STDV nisbatan kichikroq va aniqlilik yuqoriroq

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.catplot(x="Gender",y="Height",data = Obesity_level, kind="box" )
plt.show()

# %% [markdown]
# Boyda ham huddi shu narsani korishimiz mumkin, erkaklarda 2ta outlier bor.
# Erkaklarning ortacha qiymati nisbatan balandroq.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g = sns.catplot(x="Gender", y="Weight", data=Obesity_level, kind="box", order=["Male", "Female"])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
g = sns.catplot(x="Gender", y="Height", data=Obesity_level, kind="box", order=["Male", "Female"])
plt.show()

# %% [markdown]
# Yuqoridagi 2ta barni endi ozimiz hoxlagan tartibda ornini alishtirib korishimiz mumkin.

# %%
def change(num):
    x = list(str(int(num)))
    x[-1] = '0'
    return int(''.join(x))

Obesity_level['new_weight'] = Obesity_level['Weight'].agg(change)
Obesity_level['new_age'] = Obesity_level['Age'].agg(change)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3284\398404880.py:6: FutureWarning: using <function change at 0x000001DFBDD82020> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   Obesity_level['new_weight'] = Obesity_level['Weight'].agg(change)
# C:\Users\user\AppData\Local\Temp\ipykernel_3284\398404880.py:7: FutureWarning: using <function change at 0x000001DFBDD82020> in Series.agg cannot aggregate and has been deprecated. Use Series.transform to keep behavior unchanged.
#   Obesity_level['new_age'] = Obesity_level['Age'].agg(change)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Read the CSV file using pandas
# Obesity_level = pd.read_csv("Obesity Levels.csv")

# Create a point plot
sns.catplot(x="new_age", y="new_weight", data=Obesity_level, hue="Gender", kind="point")

# Show the plot
plt.show()

# %% [markdown]
# Bunda biz yosh va vaznni ortacha qiymatlari ortasida qanday trend bor yoqligini korishimiz mumkin.
#
# Shu bilan birga ularning har yoshdagi ortacha qiymati va uni atrofidagi chetlashishlarni korishmiz mumkin
